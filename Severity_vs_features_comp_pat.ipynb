# %% [markdown]
# ## Viewing associations between severity and feautures using incorrectly classified samples (Random Forest Classification)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

from scipy.stats import chi2_contingency
from scipy.stats import chi2

# %%
data = pd.read_csv("OSA_complete_patients.csv")
# missing values in original df were replaced with 0 for categorical and average for continuous variables

# %% [markdown]
# ### Train Test Split

# %%
features = ['Sex', 'Age', 'Current_smoker', 'Former_smoker',
       'Sedentary', 'Height', 'Weight', 'Cervical_perimeter',
       'Abdominal_perimeter', 'Systolic_BP', 'Diastolic_BP',
       'Maxillofacial_profile', 'BMI', 'High_BP', 'Asthma', 'Rhinitis', 'COPD',
       'Respiratory_fail', 'Myocardial_infarct', 'Coronary_fail',
       'Arrhythmias', 'Stroke', 'Heart_fail', 'Arteriopathy', 'Gastric_reflux',
       'Glaucoma', 'Diabetes', 'Hypercholesterolemia', 'Hypertriglyceridemia',
       'Hypo(er)thyroidism', 'Depression', 'Obesity', 'Dysmorphology',
       'Restless_Leg_Syndrome', 'Snoring', 'Diurnal_somnolence',
       'Driving_drowsiness', 'Morning_fatigue', 'Morning_headache',
       'Memory_problem', 'Nocturnal_perspiration',
       'Shortness_of_breath_on_exertion', 'Nocturia', 'Drowsiness_accident',
       'Near_miss_accident', 'Respiratory_arrest', 'Epworth_scale',
       'Pichots_scale', 'Depression_scale']
X=data[features]  # Features  
y=data['Severity']  # Labels

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.2, 
                                                    random_state=0, 
                                                    shuffle=True, 
                                                    stratify=y)

# %% [markdown]
# ### Random Forest Classifier

# %%
clf=RandomForestClassifier(n_estimators=100, class_weight='balanced', random_state = 0)  #defining classifier method

clf.fit(X_train,y_train)                   # training classifier

y_pred=clf.predict(X_test)                  # testing classifier 

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.4598991750687443

# %% [markdown]
# ### Creating df of actual vs predicted results

# %%
accuracy_df=pd.DataFrame({'Actual':y_test, 'Predicted':y_pred})
#accuracy_df.to_csv("accuracy_df.csv")

# %%
accuracy_df.head()
# Out:
#        Actual  Predicted
# 2239        0          0
# 15290       1          3
# 12811       3          3
# 14762       0          1
# 19532       1          2

# %%
accuracy_df.shape
# Out:
# (4364, 2)

# %%
X_test.head()
# Out:
#        Sex        Age  Current_smoker  Former_smoker  Sedentary  Height  \
# 2239   2.0  34.863792             0.0            0.0        0.0   168.0
# 15290  1.0  56.731006             0.0            0.0        1.0   157.0
# 12811  2.0  62.433949             0.0            0.0        0.0   150.0
# 14762  2.0  28.917180             0.0            0.0        0.0   163.0
# 19532  2.0  55.748118             0.0            0.0        1.0   163.0
#
#        Weight  Cervical_perimeter  Abdominal_perimeter  Systolic_BP  ...  \
# 2239     86.0                37.0                 97.0        120.0  ...
# 15290    78.0                40.0                 98.0        125.0  ...
# 12811    55.0                34.0                 92.0        135.0  ...
# 14762    89.0                41.0                115.0        120.0  ...
# 19532    73.0                36.0                 89.0        180.0  ...
#
#        Memory_problem  Nocturnal_perspiration  \
# 2239              0.0                     1.0
# 15290             1.0                     1.0
# 12811             0.0                     1.0
# 14762             1.0                     1.0
# 19532             0.0                     1.0
#
#        Shortness_of_breath_on_exertion  Nocturia  Drowsiness_accident  \
# 2239                               1.0       0.0                  0.0
# 15290                              1.0       1.0                  0.0
# 12811                              1.0       1.0                  0.0
# 14762                              1.0       0.0                  0.0
# 19532                              1.0       1.0                  0.0
#
#        Near_miss_accident  Respiratory_arrest  Epworth_scale  Pichots_scale  \
# 2239                  0.0                 0.0            5.0           15.0
# 15290                 1.0                 0.0           19.0           24.0
# 12811                 0.0                 0.0           21.0           17.0
# 14762                 0.0                 0.0            5.0            5.0
# 19532                 0.0                 1.0            3.0           11.0
#
#        Depression_scale
# 2239                2.0
# 15290              13.0
# 12811               0.0
# 14762               0.0
# 19532               1.0
#
# [5 rows x 49 columns]

# %%
X_test.shape
# Out:
# (4364, 49)

# %% [markdown]
# ### Merging X_test and accuracy dataframes

# %%
feat_sev_all = X_test.join(accuracy_df)

# %%
feat_sev_all.shape
# Out:
# (4364, 51)

# %%
feat_sev_all.head()
# Out:
#        Sex        Age  Current_smoker  Former_smoker  Sedentary  Height  \
# 2239   2.0  34.863792             0.0            0.0        0.0   168.0
# 15290  1.0  56.731006             0.0            0.0        1.0   157.0
# 12811  2.0  62.433949             0.0            0.0        0.0   150.0
# 14762  2.0  28.917180             0.0            0.0        0.0   163.0
# 19532  2.0  55.748118             0.0            0.0        1.0   163.0
#
#        Weight  Cervical_perimeter  Abdominal_perimeter  Systolic_BP  ...  \
# 2239     86.0                37.0                 97.0        120.0  ...
# 15290    78.0                40.0                 98.0        125.0  ...
# 12811    55.0                34.0                 92.0        135.0  ...
# 14762    89.0                41.0                115.0        120.0  ...
# 19532    73.0                36.0                 89.0        180.0  ...
#
#        Shortness_of_breath_on_exertion  Nocturia  Drowsiness_accident  \
# 2239                               1.0       0.0                  0.0
# 15290                              1.0       1.0                  0.0
# 12811                              1.0       1.0                  0.0
# 14762                              1.0       0.0                  0.0
# 19532                              1.0       1.0                  0.0
#
#        Near_miss_accident  Respiratory_arrest  Epworth_scale  Pichots_scale  \
# 2239                  0.0                 0.0            5.0           15.0
# 15290                 1.0                 0.0           19.0           24.0
# 12811                 0.0                 0.0           21.0           17.0
# 14762                 0.0                 0.0            5.0            5.0
# 19532                 0.0                 1.0            3.0           11.0
#
#        Depression_scale  Actual  Predicted
# 2239                2.0       0          0
# 15290              13.0       1          3
# 12811               0.0       3          3
# 14762               0.0       0          1
# 19532               1.0       1          2
#
# [5 rows x 51 columns]

# %% [markdown]
# ### Extracting incorrect predictions

# %%
feat_sev_inc = feat_sev_all.drop(feat_sev_all[feat_sev_all.Actual == feat_sev_all.Predicted].index)

# %%
feat_sev_inc.head()
# Out:
#        Sex        Age  Current_smoker  Former_smoker  Sedentary  Height  \
# 15290  1.0  56.731006             0.0            0.0        1.0   157.0
# 14762  2.0  28.917180             0.0            0.0        0.0   163.0
# 19532  2.0  55.748118             0.0            0.0        1.0   163.0
# 19991  2.0  55.145791             1.0            0.0        0.0   165.0
# 20495  1.0  35.605749             0.0            1.0        0.0   182.0
#
#        Weight  Cervical_perimeter  Abdominal_perimeter  Systolic_BP  ...  \
# 15290    78.0                40.0                 98.0        125.0  ...
# 14762    89.0                41.0                115.0        120.0  ...
# 19532    73.0                36.0                 89.0        180.0  ...
# 19991    80.0                36.0                100.0        155.0  ...
# 20495    73.0                36.0                 87.0        120.0  ...
#
#        Shortness_of_breath_on_exertion  Nocturia  Drowsiness_accident  \
# 15290                              1.0       1.0                  0.0
# 14762                              1.0       0.0                  0.0
# 19532                              1.0       1.0                  0.0
# 19991                              1.0       1.0                  0.0
# 20495                              1.0       0.0                  0.0
#
#        Near_miss_accident  Respiratory_arrest  Epworth_scale  Pichots_scale  \
# 15290                 1.0                 0.0           19.0           24.0
# 14762                 0.0                 0.0            5.0            5.0
# 19532                 0.0                 1.0            3.0           11.0
# 19991                 0.0                 0.0           12.0           11.0
# 20495                 1.0                 0.0           16.0           28.0
#
#        Depression_scale  Actual  Predicted
# 15290              13.0       1          3
# 14762               0.0       0          1
# 19532               1.0       1          2
# 19991              13.0       2          1
# 20495              12.0       1          0
#
# [5 rows x 51 columns]

# %%
feat_sev_inc.shape
# Out:
# (2357, 51)

# %%
#feat_sev_inc.to_csv("incorrect_severity_all.csv")

# %%
#feat_sev_inc = pd.read_csv("incorrect_severity_all.csv") # use this when you close and reopen the notebook so you're working with the same data

# %% [markdown]
# ### Subsetting into smaller dataframes by actual severity values

# %% [markdown]
# #### Severity = 0

# %%
inc_sev0 = feat_sev_inc.loc[feat_sev_inc['Actual'] == 0]

# %%
inc_sev0.head()
# Out:
#        Sex        Age  Current_smoker  Former_smoker  Sedentary  Height  \
# 14762  2.0  28.917180             0.0            0.0        0.0   163.0
# 4348   1.0  47.159480             0.0            1.0        0.0   181.0
# 11439  2.0  24.366872             1.0            0.0        0.0   153.0
# 7295   1.0  34.151951             0.0            1.0        0.0   182.0
# 10661  1.0  43.953457             0.0            0.0        0.0   173.0
#
#        Weight  Cervical_perimeter  Abdominal_perimeter  Systolic_BP  ...  \
# 14762    89.0                41.0                115.0        120.0  ...
# 4348     86.0                42.0                 98.0        120.0  ...
# 11439    95.0                36.0                124.0        120.0  ...
# 7295     75.0                38.0                 88.0        120.0  ...
# 10661    82.0                42.0                104.0        124.0  ...
#
#        Shortness_of_breath_on_exertion  Nocturia  Drowsiness_accident  \
# 14762                              1.0       0.0                  0.0
# 4348                               0.0       0.0                  0.0
# 11439                              0.0       1.0                  0.0
# 7295                               0.0       1.0                  0.0
# 10661                              1.0       0.0                  0.0
#
#        Near_miss_accident  Respiratory_arrest  Epworth_scale  Pichots_scale  \
# 14762                 0.0                 0.0            5.0            5.0
# 4348                  0.0                 1.0           12.0            5.0
# 11439                 0.0                 0.0            1.0            8.0
# 7295                  0.0                 0.0           11.0            3.0
# 10661                 0.0                 0.0            8.0           16.0
#
#        Depression_scale  Actual  Predicted
# 14762               0.0       0          1
# 4348                1.0       0          3
# 11439               2.0       0          1
# 7295                0.0       0          1
# 10661               1.0       0          3
#
# [5 rows x 51 columns]

# %%
inc_sev0.shape
# Out:
# (434, 51)

# %% [markdown]
# #### Severity = 1

# %%
inc_sev1 = feat_sev_inc.loc[feat_sev_inc['Actual'] == 1]

# %%
inc_sev1.head()
# Out:
#        Sex        Age  Current_smoker  Former_smoker  Sedentary  Height  \
# 15290  1.0  56.731006             0.0            0.0        1.0   157.0
# 19532  2.0  55.748118             0.0            0.0        1.0   163.0
# 20495  1.0  35.605749             0.0            1.0        0.0   182.0
# 2463   2.0  56.596851             0.0            0.0        1.0   165.0
# 17921  2.0  69.683778             0.0            0.0        0.0   149.0
#
#        Weight  Cervical_perimeter  Abdominal_perimeter  Systolic_BP  ...  \
# 15290    78.0                40.0                 98.0        125.0  ...
# 19532    73.0                36.0                 89.0        180.0  ...
# 20495    73.0                36.0                 87.0        120.0  ...
# 2463     90.0                38.0                109.0        140.0  ...
# 17921    88.0                42.0                125.0        130.0  ...
#
#        Shortness_of_breath_on_exertion  Nocturia  Drowsiness_accident  \
# 15290                              1.0       1.0                  0.0
# 19532                              1.0       1.0                  0.0
# 20495                              1.0       0.0                  0.0
# 2463                               1.0       0.0                  0.0
# 17921                              0.0       1.0                  0.0
#
#        Near_miss_accident  Respiratory_arrest  Epworth_scale  Pichots_scale  \
# 15290                 1.0                 0.0           19.0           24.0
# 19532                 0.0                 1.0            3.0           11.0
# 20495                 1.0                 0.0           16.0           28.0
# 2463                  0.0                 0.0            1.0           10.0
# 17921                 0.0                 0.0            6.0           17.0
#
#        Depression_scale  Actual  Predicted
# 15290              13.0       1          3
# 19532               1.0       1          2
# 20495              12.0       1          0
# 2463                4.0       1          3
# 17921              12.0       1          3
#
# [5 rows x 51 columns]

# %%
inc_sev1.shape
# Out:
# (689, 51)

# %% [markdown]
# #### Severity = 2

# %%
inc_sev2 = feat_sev_inc.loc[feat_sev_inc['Actual'] == 2]

# %%
inc_sev2.head()
# Out:
#        Sex        Age  Current_smoker  Former_smoker  Sedentary  Height  \
# 19991  2.0  55.145791             1.0            0.0        0.0   165.0
# 14269  1.0  66.669405             0.0            1.0        0.0   174.0
# 19377  2.0  58.414784             0.0            1.0        0.0   166.0
# 19625  2.0  67.063655             0.0            0.0        0.0   160.0
# 11742  1.0  59.975359             1.0            0.0        0.0   164.0
#
#        Weight  Cervical_perimeter  Abdominal_perimeter  Systolic_BP  ...  \
# 19991    80.0                36.0                100.0        155.0  ...
# 14269    96.0                42.0                120.0        130.0  ...
# 19377    78.0                37.0                105.0        129.0  ...
# 19625    78.0                38.0                104.0        160.0  ...
# 11742    75.0                42.0                 98.0        130.0  ...
#
#        Shortness_of_breath_on_exertion  Nocturia  Drowsiness_accident  \
# 19991                              1.0       1.0                  0.0
# 14269                              1.0       1.0                  0.0
# 19377                              1.0       0.0                  0.0
# 19625                              1.0       1.0                  0.0
# 11742                              0.0       0.0                  0.0
#
#        Near_miss_accident  Respiratory_arrest  Epworth_scale  Pichots_scale  \
# 19991                 0.0                 0.0           12.0           11.0
# 14269                 0.0                 1.0           12.0           17.0
# 19377                 0.0                 1.0           12.0           19.0
# 19625                 0.0                 1.0            8.0           11.0
# 11742                 0.0                 0.0            2.0            9.0
#
#        Depression_scale  Actual  Predicted
# 19991              13.0       2          1
# 14269               5.0       2          3
# 19377               6.0       2          3
# 19625               3.0       2          3
# 11742               7.0       2          1
#
# [5 rows x 51 columns]

# %%
inc_sev2.shape
# Out:
# (896, 51)

# %% [markdown]
# #### Severity = 3

# %%
inc_sev3 = feat_sev_inc.loc[feat_sev_inc['Actual'] == 3]

# %%
inc_sev3.head()
# Out:
#        Sex        Age  Current_smoker  Former_smoker  Sedentary  Height  \
# 16716  1.0  39.164956             0.0            0.0        0.0   175.0
# 2226   1.0  47.041752             0.0            1.0        0.0   176.0
# 7605   2.0  40.479124             0.0            1.0        0.0   160.0
# 1852   2.0  61.338809             0.0            0.0        0.0   165.0
# 13448  2.0  46.499658             0.0            1.0        0.0   165.0
#
#        Weight  Cervical_perimeter  Abdominal_perimeter  Systolic_BP  ...  \
# 16716    75.0                30.0                 92.0        120.0  ...
# 2226     88.0                36.0                 94.0        160.0  ...
# 7605     80.0                34.0                 93.0        120.0  ...
# 1852     57.0                33.0                 81.0        140.0  ...
# 13448    98.0                41.0                118.0        140.0  ...
#
#        Shortness_of_breath_on_exertion  Nocturia  Drowsiness_accident  \
# 16716                              0.0       0.0                  0.0
# 2226                               1.0       1.0                  0.0
# 7605                               1.0       1.0                  0.0
# 1852                               1.0       1.0                  0.0
# 13448                              1.0       0.0                  0.0
#
#        Near_miss_accident  Respiratory_arrest  Epworth_scale  Pichots_scale  \
# 16716                 0.0                 0.0            1.0            5.0
# 2226                  0.0                 0.0           13.0           16.0
# 7605                  0.0                 1.0            9.0            3.0
# 1852                  0.0                 0.0            7.0           14.0
# 13448                 0.0                 0.0            6.0            3.0
#
#        Depression_scale  Actual  Predicted
# 16716               1.0       3          1
# 2226                6.0       3          2
# 7605                9.0       3          1
# 1852                3.0       3          1
# 13448               2.0       3          2
#
# [5 rows x 51 columns]

# %%
inc_sev3.shape
# Out:
# (338, 51)

# %% [markdown]
# ## Association testing

# %% [markdown]
# #### Will be using the Kruskal-Wallis test to test association between continuous variables and predicted severity
# null hypothesis: the median value for the continuous feature is the same for all severities (p-value <0.05 indicates you can reject null hypothesis)
# test assumptions:
#     1. Samples are random samples, or allocation to treatment group is random.
#     2. The two samples are mutually independent.
#     3. The measurement scale is at least ordinal, and the variable is continuous.
#
# #continuous = ['PatientID','Age','Height','Weight','Cervical_perimeter','Abdominal_perimeter','Systolic_BP','Diastolic_BP',
#               'BMI','Epworth_scale','Pichots_scale','Depression_scale']

# %% [markdown]
# #### Spearman's correlation will be used to test association between categorical variables and predicted severity
# null hypothesis: there is no association between the feature and the severity (p-value <0.05 indicates you can reject null hypothesis)
# test assumptions:
#       1. Your two variables should be measured on an ordinal, interval or ratio scale.
#       2. Your two variables represent paired observations.
#       3. There is a monotonic relationship between the two variables. *** Check to make sure this assumption is met

# %% [markdown]
# ### Kruskal Wallis

# %%
from scipy import stats

# %% [markdown]
# #### Creating a function to apply kruskall Wallis to continuous variables and return p-values in a list

# %%
continuous = ['Age','Height','Weight','Cervical_perimeter','Abdominal_perimeter','Systolic_BP','Diastolic_BP', 'BMI','Epworth_scale','Pichots_scale','Depression_scale']
def kruskall_pval(df):
    p_vals = []
    for feature in continuous:
        p_val = stats.kruskal(*[group[feature].values for name, group in df.groupby("Predicted")])[1]
        p_vals.append(p_val)
    return p_vals

# %%
sev0_inc_k_pvals = kruskall_pval(inc_sev0)
sev1_inc_k_pvals = kruskall_pval(inc_sev1)
sev2_inc_k_pvals = kruskall_pval(inc_sev2)
sev3_inc_k_pvals = kruskall_pval(inc_sev3)

# %%
sev0_inc_k_pvals
# Out:
# [1.748165280930878e-08,
#  3.0162797038223118e-05,
#  1.84483584185186e-15,
#  6.628862706667371e-30,
#  3.402837253403987e-22,
#  2.231960646514679e-08,
#  2.0109073996438527e-05,
#  3.89185167693502e-12,
#  0.6489928445801499,
#  0.8970219138928452,
#  0.9228404947089156]

# %% [markdown]
# ### Chi square for categorical variables

# %%
features = ['Sex', 'Age', 'Current_smoker', 'Former_smoker',
       'Sedentary', 'Height', 'Weight', 'Cervical_perimeter',
       'Abdominal_perimeter', 'Systolic_BP', 'Diastolic_BP',
       'Maxillofacial_profile', 'BMI', 'High_BP', 'Asthma', 'Rhinitis', 'COPD',
       'Respiratory_fail', 'Myocardial_infarct', 'Coronary_fail',
       'Arrhythmias', 'Stroke', 'Heart_fail', 'Arteriopathy', 'Gastric_reflux',
       'Glaucoma', 'Diabetes', 'Hypercholesterolemia', 'Hypertriglyceridemia',
       'Hypo(er)thyroidism', 'Depression', 'Obesity', 'Dysmorphology',
       'Restless_Leg_Syndrome', 'Snoring', 'Diurnal_somnolence',
       'Driving_drowsiness', 'Morning_fatigue', 'Morning_headache',
       'Memory_problem', 'Nocturnal_perspiration',
       'Shortness_of_breath_on_exertion', 'Nocturia', 'Drowsiness_accident',
       'Near_miss_accident', 'Respiratory_arrest', 'Epworth_scale',
       'Pichots_scale', 'Depression_scale']

# %%
categorical = [i for i in features if i not in continuous]
categorical
# Out:
# ['Sex',
#  'Current_smoker',
#  'Former_smoker',
#  'Sedentary',
#  'Maxillofacial_profile',
#  'High_BP',
#  'Asthma',
#  'Rhinitis',
#  'COPD',
#  'Respiratory_fail',
#  'Myocardial_infarct',
#  'Coronary_fail',
#  'Arrhythmias',
#  'Stroke',
#  'Heart_fail',
#  'Arteriopathy',
#  'Gastric_reflux',
#  'Glaucoma',
#  'Diabetes',
#  'Hypercholesterolemia',
#  'Hypertriglyceridemia',
#  'Hypo(er)thyroidism',
#  'Depression',
#  'Obesity',
#  'Dysmorphology',
#  'Restless_Leg_Syndrome',
#  'Snoring',
#  'Diurnal_somnolence',
#  'Driving_drowsiness',
#  'Morning_fatigue',
#  'Morning_headache',
#  'Memory_problem',
#  'Nocturnal_perspiration',
#  'Shortness_of_breath_on_exertion',
#  'Nocturia',
#  'Drowsiness_accident',
#  'Near_miss_accident',
#  'Respiratory_arrest']

# %% [markdown]
# #### Function to extract p-values from chisq test

# %%
def chisq_pval(df):
    p_vals = []
    for feature in categorical:
        table = pd.crosstab(df[feature],df['Predicted'],margins = False)
        stat, p, dof, expected = chi2_contingency(table)
        p_vals.append(p)
       
    return p_vals

# %%
sev0_inc_x2_pvals = chisq_pval(inc_sev0)
sev1_inc_x2_pvals = chisq_pval(inc_sev1)
sev2_inc_x2_pvals = chisq_pval(inc_sev2)
sev3_inc_x2_pvals = chisq_pval(inc_sev3)

# %%
sev0_inc_x2_pvals
# Out:
# [3.034612278301051e-14,
#  0.20571924160456442,
#  0.0015766416363303332,
#  0.8062120725487937,
#  0.614602481580189,
#  2.176307694985892e-10,
#  0.30373208194652346,
#  0.04094691852760459,
#  0.31261084542094203,
#  0.5160933714037523,
#  0.032123520383921515,
#  0.0012236175138951278,
#  0.8533184336472855,
#  0.4643910382161768,
#  0.2648812071192575,
#  0.010397565690135089,
#  0.7052128609289572,
#  0.704754855049156,
#  0.009011066186067566,
#  1.8288355957146607e-08,
#  0.19429593913005416,
#  0.6963102125263008,
#  0.20974425799738008,
#  0.2061299670066291,
#  0.7664654163224374,
#  0.40423912968074893,
#  0.01712424648704245,
#  0.8115227339289305,
#  0.0034661670929311797,
#  0.13811315459082285,
#  0.07779249987070008,
#  0.4668273857933902,
#  0.22567488134742036,
#  0.9001434042269736,
#  0.0463893788268225,
#  0.6671215424083714,
#  0.07233269358275518,
#  2.6062573180469985e-05]

# %% [markdown]
# ### Combining continuous and categorical for each severity

# %%
sev0_inc_pvals = sev0_inc_k_pvals + sev0_inc_x2_pvals
sev1_inc_pvals = sev1_inc_k_pvals + sev1_inc_x2_pvals
sev2_inc_pvals = sev2_inc_k_pvals + sev2_inc_x2_pvals
sev3_inc_pvals = sev3_inc_k_pvals + sev3_inc_x2_pvals

# %% [markdown]
# ### Combining lists into df

# %%
inc_sev_pvals = pd.DataFrame({'sev0_inc_pvals': sev0_inc_pvals,'sev1_inc_pvals': sev1_inc_pvals,
                              'sev2_inc_pvals': sev2_inc_pvals,'sev3_inc_pvals': sev3_inc_pvals})
# keep in mind that the severity here refers to the actual severity. So for sev0_inc, the actual severity is 0 and it was predicted incorrectly

# %%
inc_sev_pvals.head()
# Out:
#    sev0_inc_pvals  sev1_inc_pvals  sev2_inc_pvals  sev3_inc_pvals
# 0    1.748165e-08    2.192539e-25    8.548509e-32    5.467290e-07
# 1    3.016280e-05    2.196219e-08    1.237035e-07    1.059858e-01
# 2    1.844836e-15    6.233987e-27    1.323538e-25    8.954792e-01
# 3    6.628863e-30    1.164019e-46    1.557529e-46    2.302166e-02
# 4    3.402837e-22    3.786483e-40    2.020194e-41    9.894847e-01

# %%
# naming rows
rows = continuous+categorical
inc_sev_pvals.index = rows
inc_sev_pvals.head()
# Out:
#                      sev0_inc_pvals  sev1_inc_pvals  sev2_inc_pvals  \
# Age                    1.748165e-08    2.192539e-25    8.548509e-32
# Height                 3.016280e-05    2.196219e-08    1.237035e-07
# Weight                 1.844836e-15    6.233987e-27    1.323538e-25
# Cervical_perimeter     6.628863e-30    1.164019e-46    1.557529e-46
# Abdominal_perimeter    3.402837e-22    3.786483e-40    2.020194e-41
#
#                      sev3_inc_pvals
# Age                    5.467290e-07
# Height                 1.059858e-01
# Weight                 8.954792e-01
# Cervical_perimeter     2.302166e-02
# Abdominal_perimeter    9.894847e-01

# %% [markdown]
# ## Applying association functions to correct predictions

# %%
feat_sev_cor = feat_sev_all.drop(feat_sev_all[feat_sev_all.Actual != feat_sev_all.Predicted].index)

# %%
feat_sev_cor.head()
# Out:
#        Sex        Age  Current_smoker  Former_smoker  Sedentary  Height  \
# 2239   2.0  34.863792             0.0            0.0        0.0   168.0
# 12811  2.0  62.433949             0.0            0.0        0.0   150.0
# 12503  1.0  43.846680             0.0            1.0        0.0   185.0
# 11816  1.0  58.154689             0.0            0.0        0.0   164.0
# 6096   1.0  50.080767             1.0            0.0        0.0   173.0
#
#        Weight  Cervical_perimeter  Abdominal_perimeter  Systolic_BP  ...  \
# 2239     86.0                37.0                 97.0        120.0  ...
# 12811    55.0                34.0                 92.0        135.0  ...
# 12503    82.0                39.0                 94.0        120.0  ...
# 11816    79.0                38.0                 92.0        150.0  ...
# 6096     90.0                43.0                110.0        120.0  ...
#
#        Shortness_of_breath_on_exertion  Nocturia  Drowsiness_accident  \
# 2239                               1.0       0.0                  0.0
# 12811                              1.0       1.0                  0.0
# 12503                              0.0       0.0                  0.0
# 11816                              0.0       0.0                  0.0
# 6096                               1.0       0.0                  0.0
#
#        Near_miss_accident  Respiratory_arrest  Epworth_scale  Pichots_scale  \
# 2239                  0.0                 0.0            5.0           15.0
# 12811                 0.0                 0.0           21.0           17.0
# 12503                 0.0                 0.0            7.0           12.0
# 11816                 0.0                 0.0           11.0           10.0
# 6096                  0.0                 0.0           10.0            9.0
#
#        Depression_scale  Actual  Predicted
# 2239                2.0       0          0
# 12811               0.0       3          3
# 12503               1.0       1          1
# 11816               0.0       1          1
# 6096                2.0       3          3
#
# [5 rows x 51 columns]

# %%
feat_sev_cor.shape
# Out:
# (2007, 51)

# %% [markdown]
# #### applying kruskal to correct severity df

# %%
sev_cor_k_pvals = kruskall_pval(feat_sev_cor)

# %%
sev_cor_k_pvals
# The age result is interesting. Ask about why it's 0.0
# Out:
# [3.9815836149045e-80,
#  9.580151609118055e-28,
#  9.285852305158433e-94,
#  2.9575963855617865e-169,
#  4.5033414035686724e-133,
#  3.8043737607255617e-66,
#  2.6163297682684056e-31,
#  3.082616133281036e-74,
#  0.09000224309128312,
#  0.0001765798819432906,
#  0.012625747104111849]

# %%
stats.kruskal(*[group["Age"].values for name, group in feat_sev_cor.groupby("Actual")])
# Out:
# KruskalResult(statistic=371.1205673663685, pvalue=3.9815836149045e-80)

# %% [markdown]
# #### applying chisq to correct severity df

# %%
sev_cor_x2_pvals = chisq_pval(feat_sev_cor)

# %%
sev_cor_x2_pvals
# Out:
# [1.51967221166611e-77,
#  0.12193351031880435,
#  1.169910421864382e-13,
#  0.0018169104803985455,
#  0.0028377562811755354,
#  4.0590673574185076e-41,
#  0.0003359544446534844,
#  8.993464888194076e-05,
#  9.361663271945843e-05,
#  0.12707989916274923,
#  0.0007368073134812016,
#  1.4810666909615257e-06,
#  0.000898502486779486,
#  0.0054220859098905875,
#  0.0034774873407779116,
#  0.009893533307348351,
#  6.130866560171082e-06,
#  0.8447789454368115,
#  3.4509738384859436e-14,
#  6.114418382943307e-21,
#  6.737495310837107e-06,
#  0.37432576538548784,
#  0.3480537908110146,
#  0.05178599675455684,
#  0.789505363625075,
#  0.9795757369547972,
#  9.926218097975187e-05,
#  0.35462968581318244,
#  3.7015583618124345e-06,
#  1.6508079058574976e-05,
#  3.4080829727631755e-19,
#  0.00032025691639306304,
#  2.0284911361479815e-06,
#  0.1030733693696132,
#  4.646817177697524e-12,
#  0.07539633349244074,
#  0.17569165800664355,
#  2.21550394971003e-42]

# %% [markdown]
# #### combining correct severity pval lists

# %%
sev_cor_pvals = sev_cor_k_pvals + sev_cor_x2_pvals

# %% [markdown]
# #### adding sev_cor_pval to dataframe containing incorrect severity pvals

# %%
all_sev_p_vals = inc_sev_pvals
all_sev_p_vals["sev_cor_pval"]= sev_cor_pvals

# %%
all_sev_p_vals.head()
# Out:
#                      sev0_inc_pvals  sev1_inc_pvals  sev2_inc_pvals  \
# Age                    1.748165e-08    2.192539e-25    8.548509e-32
# Height                 3.016280e-05    2.196219e-08    1.237035e-07
# Weight                 1.844836e-15    6.233987e-27    1.323538e-25
# Cervical_perimeter     6.628863e-30    1.164019e-46    1.557529e-46
# Abdominal_perimeter    3.402837e-22    3.786483e-40    2.020194e-41
#
#                      sev3_inc_pvals   sev_cor_pval
# Age                    5.467290e-07   3.981584e-80
# Height                 1.059858e-01   9.580152e-28
# Weight                 8.954792e-01   9.285852e-94
# Cervical_perimeter     2.302166e-02  2.957596e-169
# Abdominal_perimeter    9.894847e-01  4.503341e-133

# %%
#all_sev_p_vals.to_csv("all_sev_p_vals.csv")
#all_sev_p_vals = pd.read_csv("all_sev_p_vals.csv", index_col=0)

# %% [markdown]
# ### Top 5 most important features for each category

# %%
all_sev_p_vals.nsmallest(5,'sev0_inc_pvals')
# Out:
#                      sev0_inc_pvals  sev1_inc_pvals  sev2_inc_pvals  \
# Cervical_perimeter     6.628863e-30    1.164019e-46    1.557529e-46
# Abdominal_perimeter    3.402837e-22    3.786483e-40    2.020194e-41
# Weight                 1.844836e-15    6.233987e-27    1.323538e-25
# Sex                    3.034612e-14    7.158049e-22    1.404525e-17
# BMI                    3.891852e-12    1.464682e-23    1.214270e-19
#
#                      sev3_inc_pvals   sev_cor_pval
# Cervical_perimeter         0.023022  2.957596e-169
# Abdominal_perimeter        0.989485  4.503341e-133
# Weight                     0.895479   9.285852e-94
# Sex                        0.053396   1.519672e-77
# BMI                        0.655409   3.082616e-74

# %%
all_sev_p_vals.nsmallest(5,'sev1_inc_pvals')
# Out:
#                      sev0_inc_pvals  sev1_inc_pvals  sev2_inc_pvals  \
# Cervical_perimeter     6.628863e-30    1.164019e-46    1.557529e-46
# Abdominal_perimeter    3.402837e-22    3.786483e-40    2.020194e-41
# Weight                 1.844836e-15    6.233987e-27    1.323538e-25
# Age                    1.748165e-08    2.192539e-25    8.548509e-32
# BMI                    3.891852e-12    1.464682e-23    1.214270e-19
#
#                      sev3_inc_pvals   sev_cor_pval
# Cervical_perimeter     2.302166e-02  2.957596e-169
# Abdominal_perimeter    9.894847e-01  4.503341e-133
# Weight                 8.954792e-01   9.285852e-94
# Age                    5.467290e-07   3.981584e-80
# BMI                    6.554091e-01   3.082616e-74

# %%
all_sev_p_vals.nsmallest(5,'sev2_inc_pvals')
# Out:
#                      sev0_inc_pvals  sev1_inc_pvals  sev2_inc_pvals  \
# Cervical_perimeter     6.628863e-30    1.164019e-46    1.557529e-46
# Abdominal_perimeter    3.402837e-22    3.786483e-40    2.020194e-41
# Age                    1.748165e-08    2.192539e-25    8.548509e-32
# Weight                 1.844836e-15    6.233987e-27    1.323538e-25
# Systolic_BP            2.231961e-08    5.679014e-19    1.118491e-23
#
#                      sev3_inc_pvals   sev_cor_pval
# Cervical_perimeter     2.302166e-02  2.957596e-169
# Abdominal_perimeter    9.894847e-01  4.503341e-133
# Age                    5.467290e-07   3.981584e-80
# Weight                 8.954792e-01   9.285852e-94
# Systolic_BP            4.961007e-08   3.804374e-66

# %%
all_sev_p_vals.nsmallest(5,'sev3_inc_pvals')
# Out:
#                       sev0_inc_pvals  sev1_inc_pvals  sev2_inc_pvals  \
# Systolic_BP             2.231961e-08    5.679014e-19    1.118491e-23
# Age                     1.748165e-08    2.192539e-25    8.548509e-32
# Diastolic_BP            2.010907e-05    9.943009e-11    1.459947e-08
# Hypercholesterolemia    1.828836e-08    5.179547e-07    9.364602e-07
# Former_smoker           1.576642e-03    3.308032e-06    6.292396e-06
#
#                       sev3_inc_pvals  sev_cor_pval
# Systolic_BP             4.961007e-08  3.804374e-66
# Age                     5.467290e-07  3.981584e-80
# Diastolic_BP            9.590243e-05  2.616330e-31
# Hypercholesterolemia    3.004660e-03  6.114418e-21
# Former_smoker           3.703465e-03  1.169910e-13

# %%
len(sev3_inc_pvals)

# %%
all_sev_p_vals.nsmallest(5,'sev_cor_pval')
# Out:
#                      sev0_inc_pvals  sev1_inc_pvals  sev2_inc_pvals  \
# Cervical_perimeter     6.628863e-30    1.164019e-46    1.557529e-46
# Abdominal_perimeter    3.402837e-22    3.786483e-40    2.020194e-41
# Weight                 1.844836e-15    6.233987e-27    1.323538e-25
# Age                    1.748165e-08    2.192539e-25    8.548509e-32
# Sex                    3.034612e-14    7.158049e-22    1.404525e-17
#
#                      sev3_inc_pvals   sev_cor_pval
# Cervical_perimeter     2.302166e-02  2.957596e-169
# Abdominal_perimeter    9.894847e-01  4.503341e-133
# Weight                 8.954792e-01   9.285852e-94
# Age                    5.467290e-07   3.981584e-80
# Sex                    5.339568e-02   1.519672e-77
